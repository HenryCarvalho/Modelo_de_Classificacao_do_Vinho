# %% [markdown]
# # 📋 1 - Origem e Resumo dos dados.

# %% [markdown]
# *Solicitação de Citação:*
#    Este conjunto de dados está disponível ao público para pesquisa. Os detalhes estão descritos em [Cortez et al., 2009].
#
#    P. Cortez, A. Cerdeira, F. Almeida, T. Matos e J. Reis.
#    Modelagem de preferências de vinho por mineração de dados de propriedades físico-químicas.
#    Em Decision Support Systems, Elsevier, 47(4):547-553. ISSN: 0167-9236.
#
#    Disponível em: [@Elsevier] http://dx.doi.org/10.1016/j.dss.2009.05.016
#                  [Pré-impressão (pdf)] http://www3.dsi.uminho.pt/pcortez/winequality09.pdf
#                  [bib] http://www3.dsi.uminho.pt/pcortez/dss09.bib
#
# *1. Título: Qualidade do Vinho*
#
# *2. Fontes*
#     Criado por: Paulo Cortez (Univ. Minho), Antonio Cerdeira, Fernando Almeida, Telmo Matos e José Reis (CVRVV) @ 2009
#
# *3. Uso anterior:*
#
#    P. Cortez, A. Cerdeira, F. Almeida, T. Matos e J. Reis.
#    Modelagem de preferências de vinho por mineração de dados de propriedades físico-químicas.
#    Em Decision Support Systems, Elsevier, 47(4):547-553. ISSN: 0167-9236.
#
#    Na referência acima, foram criados dois conjuntos de dados, usando amostras de vinho tinto e branco.
#    As entradas incluem testes objetivos (por exemplo, valores de PH) e a saída é baseada em dados sensoriais
#    (mediana de pelo menos 3 avaliações feitas por enólogos). Cada especialista classificou a qualidade do vinho
#    entre 0 (muito ruim) e 10 (muito excelente). Vários métodos de mineração de dados foram aplicados para modelar
#    esses conjuntos de dados sob uma abordagem de regressão. O modelo de máquina de vetores de suporte alcançou o
#    melhores resultados. Várias métricas foram computadas: MAD, matriz de confusão para uma tolerância de erro fixa (T),
#    etc. Além disso, plotamos as importâncias relativas das variáveis de entrada (conforme medido por uma sensibilidade
#    procedimento de análise).
#
# *4. Informações relevantes:*
#
#     Os dois conjuntos de dados estão relacionados com as variantes tinto e branco do vinho português "Vinho Verde".
#     Para mais detalhes, consulte: http://www.vinhoverde.pt/en/ ou a referência [Cortez et al., 2009].
#     Devido a questões de privacidade e logística, apenas variáveis físico-químicas (entradas) e sensoriais (saída)
#     estão disponíveis (por exemplo, não há dados sobre tipos de uva, marca de vinho, preço de venda do vinho, etc.).
#
#     Esses conjuntos de dados podem ser vistos como tarefas de classificação ou regressão.
#     As classes são ordenadas e não equilibradas (por exemplo, há muito mais vinhos normais do que
#     excelentes ou ruins). Algoritmos de detecção de outliers podem ser usados para detectar os poucos excelentes
#     ou vinhos pobres. Além disso, não temos certeza se todas as variáveis de entrada são relevantes. Então
#     pode ser interessante testar métodos de seleção de recursos.
#
# *5. Número de instâncias: vinho tinto - 1599; vinho branco - 4898.*
#
# *6. Número de Atributos: 11 + atributo de saída*
#
#     Nota: vários dos atributos podem estar correlacionados, por isso faz sentido aplicar algum tipo de
#     seleção de recursos.
#
# *7. Informações do atributo:*
#
#     Para mais informações, leia [Cortez et al., 2009].
#
#     Variáveis de entrada (com base em testes físico-químicos):
#
# 1 - fixed acidity (acidez fixa)
#
# acidez fixa: A acidez fixa é uma característica importante que contribui para o equilíbrio e sabor do vinho. Manter um nível adequado de acidez é essencial para evitar que o vinho fique sem vida. A unidade de medida é em g/dm3.
#
# 2 - volatile acidity (acidez volátil)
#
# acidez volátil: Embora uma quantidade mínima de acidez volátil possa contribuir para a complexidade aromática do vinho, um excesso desse ácido pode resultar em aromas desagradáveis, como vinagre. A unidade de medida é em g/dm3.
#
# 3 - citric acid (ácido cítrico)
#
# ácido cítrico: O ácido cítrico pode adicionar frescor e vivacidade ao vinho, além de atuar como conservante natural. Durante a fermentação, é importante monitorar a quantidade de ácido cítrico presente, garantindo que ela esteja em equilíbrio com os outros ácidos presentes no vinho. A unidade de medida é em g/dm3.
#
# 4 - residual sugar (açúcar residual)
#
# Açúcar residual: O açúcar residual no vinho desempenha um papel crucial na doçura percebida e no equilíbrio geral da bebida. É importante garantir que o nível de açúcar residual seja adequado ao estilo do vinho desejado, levando em consideração a acidez para alcançar um equilíbrio agradável. Vinhos com mais de 45g/dm3 são considerados doces. A unidade de medida é em g/dm3.
#
# 5 - chlorides (cloretos)
#
# cloretos: Os cloretos são sais minerais presentes no vinho e podem influenciar o sabor e a estrutura.
#
# 6 - free sulfur dioxide (dióxido de enxofre livre)
#
# dióxido de enxofre livre: O dióxido de enxofre é usado como um conservante e antioxidante no vinho, mas um excesso pode afetar negativamente o aroma e o sabor. A unidade de medida é em g/dm3.
#
# 7 - total sulfur dioxide (dióxido de enxofre total)
#
# dióxido de enxofre total: A quantidade total de SO2 no vinho. Isso é adicionado para matar bactérias nocivas e preservar a qualidade e o frescor. A unidade de medida é em g/dm3.
#
# 8 - density (densidade)
#
# densidade: A densidade pode ser usada como uma medida indireta para acompanhar a conversão de açúcar em álcool durante a fermentação. Vinhos mais doces têm maior densidade.
#
# 9 - pH
#
# pH: O pH é uma medida importante da acidez do vinho e pode afetar a estabilidade, conservação e desenvolvimento microbiológico. Descreve o quão ácido ou básico é um vinho numa escala de 0 (muito ácido) a 14 (muito básico).
#
# 10 - sulphates (sulfatos)
#
# sulfatos: Os sulfatos são aditivos usados na vinificação para proteger o vinho contra a oxidação e o crescimento de bactérias indesejáveis.
#
# 11 - alcohol (álcool)
#
# álcool: O teor alcoólico do vinho é um resultado direto da fermentação do açúcar pelas leveduras. Geralmente é medido em % de volume ou álcool por volume (ABV).
# Variável de saída (com base em dados sensoriais):
#
# 12 - quality (qualidade - pontuação entre 0 e 10)
#
# qualidade: Especialistas usaram um selo de qualidade na faixa de 0 (muito ruim) a 10 (muito excelente). É a mediana de pelo menos três avaliações feitas por especialistas em vinhos.
#
# *8. Valores de atributos ausentes: nenhum*

# %% [markdown]
# # 📋 2 - Introdução:

# %% [markdown]
# Primeiramente, vamos analisar cuidadosamente os dados que possuímos. Em seguida, iremos visualizá-los posteriormente. Após isso, aprimoraremos nosso modelo de treinamento, desenvolvendo múltiplas versões simultaneamente. Por fim, compararemos o desempenho desses modelos para determinar seu sucesso.

# %% [markdown]
# # 📋 3 - Importação das bibliotecas necessárias no Python.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import squarify
import colorbrewer as cb
from sklearn.metrics import plot_confusion_matrix
from scipy.stats import norm, boxcox
from collections import Counter
from scipy import stats

# warning library
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 📋 4 - Importar Dataset

# %%
df_red = pd.read_csv('winequality-red.csv', decimal='.', sep=';')

# %%
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
print("Data Shape -->", df_red.shape)
# Out:
# Data Shape --> (1599, 12)

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
print("Data Informação")
df_red.info()
# Out:
# Data Informação
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ### 4.1 - fixed acidity - quality

# %%
df_red[["fixed acidity","quality"]].groupby(["quality"], as_index = False).mean().sort_values(by = "quality").style.background_gradient("Reds")
# Out:
# <style type="text/css">
# #T_9ef7d_row0_col0, #T_9ef7d_row1_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_9ef7d_row0_col1 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_9ef7d_row1_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_9ef7d_row2_col0 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_9ef7d_row2_col1 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_9ef7d_row3_col0 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_9ef7d_row3_col1 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_9ef7d_row4_col0 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_9ef7d_row4_col1, #T_9ef7d_row5_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_9ef7d_row5_col1 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9ef7d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# Podemos afirmar que o aumento da acidez fixa tem um impacto positivo no voto dado, porém, neste estágio, é difícil chegar a uma conclusão definitiva.

# %% [markdown]
# ### 4.2 - cidric acid - quality

# %%
df_red[["citric acid","quality"]].groupby(["quality"], as_index = False).mean().sort_values(by = "quality").style.background_gradient("Reds")
# Out:
# <style type="text/css">
# #T_9e21e_row0_col0, #T_9e21e_row0_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_9e21e_row1_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_9e21e_row1_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_9e21e_row2_col0 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_9e21e_row2_col1 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_9e21e_row3_col0 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_9e21e_row3_col1 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_9e21e_row4_col0 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_9e21e_row4_col1 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_9e21e_row5_col0, #T_9e21e_row5_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9e21e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# A partir dessa observação, fica evidente que o incremento de ácido cítrico teve um impacto positivo nos votos.

# %% [markdown]
# ### 4.3 - residual sugar - quality

# %%
df_red[["residual sugar","quality"]].groupby(["quality"], as_index = False).mean().sort_values(by = "quality").style.background_gradient("Reds")
# Out:
# <style type="text/css">
# #T_93a1f_row0_col0, #T_93a1f_row3_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_93a1f_row0_col1 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_93a1f_row1_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_93a1f_row1_col1 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
# }
# #T_93a1f_row2_col0 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_93a1f_row2_col1 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_93a1f_row3_col0 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_93a1f_row4_col0 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_93a1f_row4_col1, #T_93a1f_row5_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_93a1f_row5_col1 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_93a1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# Parece ser desafiador inferir a quantidade de açúcar residual presente neste caso.

# %% [markdown]
# ### 4.4 - chlorides - quality

# %%
df_red[["chlorides","quality"]].groupby(["quality"], as_index = False).mean().sort_values(by = "quality").style.background_gradient("Reds")
# Out:
# <style type="text/css">
# #T_84812_row0_col0, #T_84812_row5_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_84812_row0_col1, #T_84812_row5_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_84812_row1_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_84812_row1_col1 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_84812_row2_col0 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_84812_row2_col1 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_84812_row3_col0 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_84812_row3_col1 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_84812_row4_col0 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_84812_row4_col1 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# </style>
# <table id="T_84812">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# "A redução dos níveis de cloretos tem um impacto positivo nos votos manifestados."

# %% [markdown]
# ### 4.5 - free sulfur dioxide - quality

# %%
df_red[["free sulfur dioxide","quality"]].groupby(["quality"], as_index = False).mean().sort_values(by = "quality").style.background_gradient("Reds")
# Out:
# <style type="text/css">
# #T_c2897_row0_col0, #T_c2897_row0_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_c2897_row1_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_c2897_row1_col1 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_c2897_row2_col0 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_c2897_row2_col1, #T_c2897_row5_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c2897_row3_col0 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_c2897_row3_col1 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_c2897_row4_col0 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_c2897_row4_col1 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_c2897_row5_col1 {
#   background-color: #fc9070;
#   color: #000000;
# }
# </style>
# <table id="T_c2897">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# Comentar sobre o dióxido de enxofre livre também não parece ser fácil. Enquanto os níveis 13 e 14 do vinho tinto foram bem avaliados, no vinho branco os mais bem avaliados foram 36 e 33. No entanto, é importante destacar que ocorreram avaliações com valores semelhantes que receberam notas inferiores. A partir dessa análise, conclui-se que a composição do dióxido de enxofre livre tem efeitos distintos nos dois tipos de vinho.

# %% [markdown]
# ### 4.6 - total sulfur dioxide - quality

# %%
df_red[["total sulfur dioxide","quality"]].groupby(["quality"], as_index = False).mean().sort_values(by = "quality").style.background_gradient("Reds")
# Out:
# <style type="text/css">
# #T_bf908_row0_col0, #T_bf908_row0_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_bf908_row1_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_bf908_row1_col1 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_bf908_row2_col0 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_bf908_row2_col1, #T_bf908_row5_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_bf908_row3_col0 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_bf908_row3_col1 {
#   background-color: #fa6849;
#   color: #f1f1f1;
# }
# #T_bf908_row4_col0 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_bf908_row4_col1 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_bf908_row5_col1 {
#   background-color: #fcb499;
#   color: #000000;
# }
# </style>
# <table id="T_bf908">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# Comentar sobre o dióxido de enxofre total não tem nenhum significado, pois flutua com base nos votos, sem qualquer ordem discernível.

# %% [markdown]
# ### 4.7 - density - quality

# %%
df_red[["density","quality"]].groupby(["quality"], as_index = False).mean().sort_values(by = "quality").style.background_gradient("Reds")
# Out:
# <style type="text/css">
# #T_6bf63_row0_col0, #T_6bf63_row5_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_6bf63_row0_col1, #T_6bf63_row5_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_6bf63_row1_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_6bf63_row1_col1 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_6bf63_row2_col0 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_6bf63_row2_col1 {
#   background-color: #af1117;
#   color: #f1f1f1;
# }
# #T_6bf63_row3_col0 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_6bf63_row3_col1 {
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_6bf63_row4_col0 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_6bf63_row4_col1 {
#   background-color: #fc8b6b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6bf63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# "A intensidade é praticamente uniforme em todos os votos, com apenas uma leve redução perceptível. A diminuição da densidade aparenta ter um impacto positivo nos votos."

# %% [markdown]
# ### 4.8 - pH - quality

# %%
df_red[["pH","quality"]].groupby(["quality"], as_index = False).mean().sort_values(by = "quality").style.background_gradient("Reds")
# Out:
# <style type="text/css">
# #T_28973_row0_col0, #T_28973_row5_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_28973_row0_col1, #T_28973_row5_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_28973_row1_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_28973_row1_col1 {
#   background-color: #a50f15;
#   color: #f1f1f1;
# }
# #T_28973_row2_col0 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_28973_row2_col1 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_28973_row3_col0 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_28973_row3_col1 {
#   background-color: #fc8e6e;
#   color: #000000;
# }
# #T_28973_row4_col0 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_28973_row4_col1 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# </style>
# <table id="T_28973">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# Podemos afirmar que a redução do pH tem um impacto favorável nos votos atribuídos ao vinho tinto, mas, ao mesmo tempo, exerce um efeito adverso nos votos dados ao vinho branco.

# %% [markdown]
# ### 4.9 - sulphates - quality

# %%
df_red[["sulphates","quality"]].groupby(["quality"], as_index = False).mean().sort_values(by = "quality").style.background_gradient("Reds")
# Out:
# <style type="text/css">
# #T_2d3a9_row0_col0, #T_2d3a9_row0_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_2d3a9_row1_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_2d3a9_row1_col1 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_2d3a9_row2_col0 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_2d3a9_row2_col1 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_2d3a9_row3_col0 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_2d3a9_row3_col1 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_2d3a9_row4_col0 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_2d3a9_row4_col1 {
#   background-color: #a81016;
#   color: #f1f1f1;
# }
# #T_2d3a9_row5_col0, #T_2d3a9_row5_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2d3a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# A partir deste ponto, torna-se evidente que o aumento de sulfatos tem um efeito benéfico no vinho tinto, porém, no caso do vinho branco, não podemos afirmar com certeza se há uma ordem discernível.

# %% [markdown]
# ### 4.9.1 - alcohol - quality

# %%
df_red[["alcohol","quality"]].groupby(["quality"], as_index = False).mean().sort_values(by = "quality").style.background_gradient("Reds")
# Out:
# <style type="text/css">
# #T_3bca2_row0_col0, #T_3bca2_row2_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_3bca2_row0_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_3bca2_row1_col0 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_3bca2_row1_col1 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_3bca2_row2_col0 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_3bca2_row3_col0 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_3bca2_row3_col1 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_3bca2_row4_col0 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_3bca2_row4_col1 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_3bca2_row5_col0, #T_3bca2_row5_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3bca2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# De maneira geral, pode-se afirmar que o aumento da proporção de álcool influencia positivamente a percepção dos votos em relação aos dois vinhos.

# %% [markdown]
# # 📋 5 - Missing Value

# %% [markdown]
# Vamos analisar se há algum dado ausente em nosso conjunto de dados e, caso existam, faremos o possível para eliminá-los.

# %%
print("Existem colunas com valores nulos em nossos dados?")
df_red.columns[df_red.isnull().any()]
# Out:
# Existem colunas com valores nulos em nossos dados?
# Index([], dtype='object')

# %%
df_red.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Observamos a ausência de dados faltantes em nossos conjuntos de dados.

# %% [markdown]
# # 📋 6 - Visualization

# %% [markdown]
# <h1 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold"><p>Nesta seção, iremos analisar visualmente cada um dos nossos recursos e examinaremos os dados por meio de gráficos.</p>
# </h1>

# %% [markdown]
# <h2 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" > Fixed Acidity </p> </li>
#         <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" > Volatile Acidity </p> </li>
#         <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >Citric Acid </p> </li>
#         <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" > Residual Sugar </p> </li>
#             <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >Chlorides </p> </li>
#                 <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >Free Sulfur Dioxide </p> </li>
#                 <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >Total Sulfur Dioxide </p> </li>
#                     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >Density </p> </li>
#                     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >PH </p> </li>
#                     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >Sulphates </p> </li>
#                     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >Alcohol </p> </li>
#                     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >Quality </p> </li>
# </ul>
# </h2>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Fixed Acidity</h3>

# %%
# Vinho tinto

quality = [3,4,5,6,7,8]
mediadeacidezfixa = []

for cada in quality:
    x = df_red[df_red["quality"] == cada]
    mean = x["fixed acidity"].mean()
    mediadeacidezfixa.append(mean)


plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
plt.hist(df_red["fixed acidity"], color="purple")
plt.xlabel("fixed acidity")
plt.ylabel("Frequency")
plt.title("Histograma da Acidez Fixa", color = "black", fontweight='bold', fontsize = 11)
plt.subplot(2,2,2)
sns.distplot(df_red["fixed acidity"], fit=norm, color="purple")
plt.title("Distribuição(Distplot) de Acidez Fixa", color = "black", fontweight='bold', fontsize = 11)
plt.subplot(2,2,3)
sns.barplot(x = quality, y = mediadeacidezfixa, palette="PuRd")
plt.title("O valor médio da Acidez Fixa por Qualidade", color = "black", fontweight='bold', fontsize = 11)
plt.xlabel("fixed acidity")
plt.ylabel("Frequency")
plt.subplot(2,2,4)
sns.boxplot(df_red['quality'], df_red["fixed acidity"], palette='PuRd')
plt.title("Acidez Fixa e Qualidade", color = "black", fontweight= 'bold', fontsize = 11)

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >A acidez fixa pode ter um impacto limitado na divisão dos votos do vinho tinto.</p> </li>
#         <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >No 2º gráfico de distribuição, observamos uma assimetria à direita na linha roxa em relação à linha preta, que representa os dados normalizados. É necessário corrigir essa discrepância.</p> </li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Volatile Acidity</h3>

# %%
# Vinho Tinto

volatileAcidityMean = []

for cada in quality:
    x = df_red[df_red["quality"] == cada]
    mean = x["volatile acidity"].mean()
    volatileAcidityMean.append(mean)


plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
plt.hist(df_red["volatile acidity"], color="purple")
plt.xlabel("volatile acidity")
plt.ylabel("Frequency")
plt.title("Histograma de Acidez Volátil", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,2)
sns.distplot(df_red["volatile acidity"], fit=norm, color="purple")
plt.title("Distribuição(Distplot) de Acidez Volátil", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,3)
sns.barplot(x = quality, y = volatileAcidityMean, palette= "PuRd")
plt.title("O valor médio da Acidez Volátil por Qualidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.xlabel("quality")
plt.ylabel("volatile acidity mean")
plt.subplot(2,2,4)
sns.boxplot(df_red['quality'], df_red["volatile acidity"], palette='PuRd')
plt.title("Acidez Volátil e Qualidade", color = "black", fontweight= 'bold', fontsize = 11)

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >A redução da acidez volátil demonstra ter um impacto positivo nos votos do vinho tinto.</p> </li>
#         <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Ao analisarmos o segundo gráfico, podemos observar uma distribuição satisfatória.</p> </li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">citric acid</h3>

# %%
# Vinho Tinto

citricAcidMean = []

for cada in quality:
    x = df_red[df_red["quality"] == cada]
    mean = x["citric acid"].mean()
    citricAcidMean.append(mean)


plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
plt.hist(df_red["citric acid"], color="purple")
plt.xlabel("citric acid")
plt.ylabel("Frequency")
plt.title("Histograma de Ácido Cítrico", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,2)
sns.distplot(df_red["citric acid"], fit=norm, color="purple")
plt.title("Distribuição(Distplot) de Ácido Cítrico", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,3)
sns.barplot(x = quality, y = citricAcidMean, palette= "PuRd")
plt.title("O valor médio do Ácido Cítrico por Qualidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.xlabel("quality")
plt.ylabel("citric acid mean")
plt.subplot(2,2,4)
sns.boxplot(df_red['quality'], df_red["citric acid"], palette='PuRd')
plt.title("Ácido Cítrico e Qualidade", color = "black", fontweight= 'bold', fontsize = 11)

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Podemos afirmar que o incremento do ácido cítrico tem um impacto favorável sobre a contagem de votos vinho tinto.</p> </li>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >No segundo gráfico de distribuição, é necessário fazer um ajuste sutil.</p> </li>
# </ul>
# <h/3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">residual sugar</h3>

# %%
# Vinho Tinto

residualSugarMean = []

for cada in quality:
    x = df_red[df_red["quality"] == cada]
    mean = x["residual sugar"].mean()
    residualSugarMean.append(mean)


plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
plt.hist(df_red["residual sugar"], color="purple")
plt.xlabel("residual sugar")
plt.ylabel("Frequency")
plt.title("Histograma de Açúcar Residual", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,2)
sns.distplot(df_red["residual sugar"], fit=norm, color="purple")
plt.title("Distribuição(Distplot) de Açúcar Residual", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,3)
sns.barplot(x = quality, y = residualSugarMean, palette= "PuRd")
plt.title("O valor médio do Açúcar Residual por Qualidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.xlabel("quality")
plt.ylabel("residual sugar mean")
plt.subplot(2,2,4)
sns.boxplot(df_red['quality'], df_red["residual sugar"], palette='PuRd')
plt.title("Açúcar Residual e Qualidade", color = "black", fontweight= 'bold', fontsize = 11)

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >A estimativa de açúcar residual parece ter um efeito insignificante no vinho tinto.</p> </li>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >De acordo com a distribuição normal, há uma tendência de assimetria para a direita.</p></li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Chlorides</h3>

# %%
# Vinho Tinto

chloridesMean = []

for cada in quality:
    x = df_red[df_red["quality"] == cada]
    mean = x["chlorides"].mean()
    chloridesMean.append(mean)


plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
plt.hist(df_red["chlorides"], color="purple")
plt.xlabel("chlorides")
plt.ylabel("Frequency")
plt.title("Histograma de Clorestos", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,2)
sns.distplot(df_red["chlorides"], fit=norm, color="purple")
plt.title("Distribuição(Distplot) de Clorestos", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,3)
sns.barplot(x = quality, y = chloridesMean, palette= "PuRd")
plt.title("O valor médio do Clorestos por Qualidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.xlabel("quality")
plt.ylabel("chlorides mean")
plt.subplot(2,2,4)
sns.boxplot(df_red['quality'], df_red["chlorides"], palette='PuRd')
plt.title("Clorestos e Qualidade", color = "black", fontweight= 'bold', fontsize = 11)

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Observamos que a redução dos cloretos possui um impacto benéfico nos votos dos vinhos tintos</p> </li>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Se olharmos para o quarto gráfico, veremos que há muitos outliers. Precisamos consertar. Caso contrário, eles afetarão negativamente nosso modelo.</p></li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Free Sulfur Dioxide</h3>

# %%
# Vinho Tinto

freeSulfurDioxideMean = []

for cada in quality:
    x = df_red[df_red["quality"] == cada]
    mean = x["free sulfur dioxide"].mean()
    freeSulfurDioxideMean.append(mean)


plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
plt.hist(df_red["free sulfur dioxide"], color="purple")
plt.xlabel("free sulfur dioxide")
plt.ylabel("Frequency")
plt.title("Histograma de Dióxido de Enxofre Livre", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,2)
sns.distplot(df_red["free sulfur dioxide"], fit=norm, color="purple")
plt.title("Distribuição(Distplot) de Dióxido de Enxofre Livre", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,3)
sns.barplot(x = quality, y = freeSulfurDioxideMean, palette= "PuRd")
plt.title("O valor médio do Dióxido de Enxofre Livre por Qualidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.xlabel("quality")
plt.ylabel("free sulfur dioxide mean")
plt.subplot(2,2,4)
sns.boxplot(df_red['quality'], df_red["free sulfur dioxide"], palette='PuRd')
plt.title("Dióxido de Enxofre Livre e Qualidade", color = "black", fontweight= 'bold', fontsize = 11)

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Ao analisarmos o segundo gráfico, percebemos uma tendência à direita com relação a linha de normalização dos vinhos tintos</p> </li>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Se olharmos para o quarto gráfico, veremos que há muitos outliers. Precisamos consertar. Caso contrário, eles afetarão negativamente nosso modelo.</p></li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Total Sulfur Dioxide</h3>

# %%
# Vinho Tinto

totalSulfurDioxideMean = []

for cada in quality:
    x = df_red[df_red["quality"] == cada]
    mean = x["total sulfur dioxide"].mean()
    totalSulfurDioxideMean.append(mean)


plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
plt.hist(df_red["total sulfur dioxide"], color="purple")
plt.xlabel("total sulfur dioxide")
plt.ylabel("Frequency")
plt.title("Histograma de Dióxido de Enxofre Total", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,2)
sns.distplot(df_red["total sulfur dioxide"], fit=norm, color="purple")
plt.title("Distribuição(Distplot) de Dióxido de Enxofre Total", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,3)
sns.barplot(x = quality, y = totalSulfurDioxideMean, palette= "PuRd")
plt.title("O valor médio do Dióxido de Enxofre Total por Qualidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.xlabel("quality")
plt.ylabel("total sulfur dioxide mean")
plt.subplot(2,2,4)
sns.boxplot(df_red['quality'], df_red["total sulfur dioxide"], palette='PuRd')
plt.title("Dióxido de Enxofre Total e Qualidade", color = "black", fontweight= 'bold', fontsize = 11)

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Ao examinarmos esses gráficos, não identificamos um padrão consistente que afete a variável de destino. Concluir de forma definitiva não é uma tarefa simples para os vinhos tintos.</p> </li>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Observamos uma tendência inclinada para a direita no segundo gráfico.</p></li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Density</h3>

# %%
# Vinho Tinto

densityMean = []

for cada in quality:
    x = df_red[df_red["quality"] == cada]
    mean = x["density"].mean()
    densityMean.append(mean)


plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
plt.hist(df_red["density"], color="purple")
plt.xlabel("density")
plt.ylabel("Frequency")
plt.title("Histograma da Densidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,2)
sns.distplot(df_red["density"], fit=norm, color="purple")
plt.title("Distribuição(Distplot) da Densidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,3)
sns.barplot(x = quality, y = densityMean, palette= "PuRd")
plt.title("O valor médio da Densidade por Qualidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.xlabel("quality")
plt.ylabel("density mean")
plt.subplot(2,2,4)
sns.boxplot(df_red['quality'], df_red["density"], palette='PuRd')
plt.title("Densidade e Qualidade", color = "black", fontweight= 'bold', fontsize = 11)

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Prever o efeito na variável alvo parece ser um desafio considerável no vinho tinto.</p> </li>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Ao observarmos o gráfico de dispersão, notamos que ele exibe uma distribuição normal.</p></li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">PH</h3>

# %%
# Vinho Tinto

pHMean = []

for cada in quality:
    x = df_red[df_red["quality"] == cada]
    mean = x["pH"].mean()
    pHMean.append(mean)


plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
plt.hist(df_red["pH"], color="purple")
plt.xlabel("pH")
plt.ylabel("Frequency")
plt.title("Histograma do PH", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,2)
sns.distplot(df_red["pH"], fit=norm, color="purple")
plt.title("Distribuição(Distplot) do PH", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,3)
sns.barplot(x = quality, y = pHMean, palette= "PuRd")
plt.title("O valor médio do PH por Qualidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.xlabel("quality")
plt.ylabel("pH mean")
plt.subplot(2,2,4)
sns.boxplot(df_red['quality'], df_red["pH"], palette='PuRd')
plt.title("PH e Qualidade", color = "black", fontweight= 'bold', fontsize = 11)

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >A diminuição do valor do pH tem um impacto positivo nos votos do vinho tinto.</p> </li>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Observamos que o gráfico de dispersão exibe valores dentro da normalidade. No entanto, no gráfico de Boxplot, é necessário identificar e remover os outliers</p> </li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Sulphates</h3>

# %%
# Vinho Tinto

sulphatesMean = []

for cada in quality:
    x = df_red[df_red["quality"] == cada]
    mean = x["sulphates"].mean()
    sulphatesMean.append(mean)


plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
plt.hist(df_red["sulphates"], color="purple")
plt.xlabel("sulphates")
plt.ylabel("Frequency")
plt.title("Histograma dos Sulfatos", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,2)
sns.distplot(df_red["sulphates"], fit=norm, color="purple")
plt.title("Distribuição(Distplot) dos Sulfatos", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,3)
sns.barplot(x = quality, y = sulphatesMean, palette= "PuRd")
plt.title("O valor médio dos Sulfatos por Qualidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.xlabel("quality")
plt.ylabel("sulphates mean")
plt.subplot(2,2,4)
sns.boxplot(df_red['quality'], df_red["sulphates"], palette='PuRd')
plt.title("Sulfatos e Qualidade", color = "black", fontweight= 'bold', fontsize = 11)

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Observamos uma relação positiva entre o aumento dos níveis de sulfatos e a quantidade de votos favoráveis no vinho tinto.</p> </li>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Devido à presença de diversos outliers no gráfico de boxplot, é necessário eliminar esses pontos discrepantes.</p></li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Alcohol</h3>

# %%
# Vinho Tinto

alcoholMean = []

for cada in quality:
    x = df_red[df_red["quality"] == cada]
    mean = x["alcohol"].mean()
    alcoholMean.append(mean)


plt.figure(figsize=(13,10))
plt.subplot(2,2,1)
plt.hist(df_red["alcohol"], color="purple")
plt.xlabel("alcohol")
plt.ylabel("Frequency")
plt.title("Histograma do Álcool", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,2)
sns.distplot(df_red["alcohol"], fit=norm, color="purple")
plt.title("Distribuição(Distplot) do Álcool", color = "black", fontweight= 'bold', fontsize = 11)
plt.subplot(2,2,3)
sns.barplot(x = quality, y = alcoholMean, palette= "PuRd")
plt.title("O valor médio do Álcool por Qualidade", color = "black", fontweight= 'bold', fontsize = 11)
plt.xlabel("quality")
plt.ylabel("alcohol mean")
plt.subplot(2,2,4)
sns.boxplot(df_red['quality'], df_red["alcohol"], palette='PuRd')
plt.title("Álcool e Qualidade", color = "black", fontweight= 'bold', fontsize = 11)

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Ao analisar o gráfico de forma geral, conclui-se que o aumento do consumo de álcool tem um impacto positivo nos votos dos vinhos tintos</p> </li>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Ao observarmos o segundo gráfico, constatamos que os dados não estão normalizados. Vamos corrigir essa questão.</p></li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Quality</h3>

# %%
# Vinho tinto


Number = df_red.quality.value_counts().values
Label = df_red.quality.value_counts().index

plt.figure(figsize=(18, 10))
plt.subplot(1, 2, 1)
sns.countplot(df_red["quality"])
plt.xlabel("quality")
plt.title("Distribuição de Qualidade", color="black", fontweight='bold', fontsize=11)
plt.subplot(1, 2, 2)

# Calcular as proporções
sizesx = Number / sum(Number)

# Definir a paleta de cores harmoniosas
colorsx = cb.Set3[len(Label)]

# Normalizar as cores para a faixa correta (0 a 1)
colors_normalizedx = [(c[0] / 255, c[1] / 255, c[2] / 255) for c in colorsx]

# Gerar as posições dos retângulos no treemap com as cores definidas
squarify.plot(sizes=sizesx, label=Label, alpha=0.8, color=colors_normalizedx)

plt.title("Distribuição de Qualidade", color="black", fontweight='bold', fontsize=11)
plt.axis('off')  # Remover os eixos

plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Nesta análise, examinamos minuciosamente a distribuição dos votos, a fim de obter insights valiosos sobre o padrão de votação.</h3>

# %% [markdown]
# <h1 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Correção de Assimetria</h1>

# %% [markdown]
# <h2 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <p style = "background:black;color:white;font-family:Arial;font-weight:bold" >Nesta seção, buscaremos corrigir a assimetria em determinados aspectos dos nossos dados de vinho tinto, utilizando gráficos para visualizá-los.</p>
# </h2>

# %% [markdown]
# <h2 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" > Acidez Fixa </p> </li>
#         <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" > Açúcar Residual </p> </li>
#                 <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" > Dióxido de Enxofre Livre </p> </li>
#                 <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" > Dióxido de Enxofre Total </p> </li>
#                     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" > Álcool </p> </li>
#
# </ul>
# </h2>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Acidez Fixa</h3>

# %%
# Ajustando uma distribuição normal aos valores da coluna "fixed acidity" do DataFrame.
(mu, sigma) = norm.fit(df_red["fixed acidity"])
print("mu {} : {}, sigma {} : {}".format("fixed acidity", mu, "fixed acidity", sigma))
# Out:
# mu fixed acidity : 8.31963727329581, sigma fixed acidity : 1.7405518001102729

# %%
# cria uma figura com dois subplots lado a lado, esses gráficos são úteis para visualizar a distribuição e a normalidade dos dados.
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df_red["fixed acidity"], fit=norm, color="purple")
plt.title("Acidez Fixa Distplot", color = "darkred")
plt.subplot(1,2,2)
stats.probplot(df_red["fixed acidity"], plot = plt)
plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >No segundo gráfico, observamos claramente a presença de assimetria.</p> </li>
# </ul>
# </h3>

# %%
# Utilizar a função Box-Cox para transformação estatística de estabilizar a variância e melhorar a normalidade dos dados.
df_red["fixed acidity"], lam_fixed_acidity = boxcox(df_red["fixed acidity"])

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Tentaremos eliminar a assimetria aqui usando box cox.</p> </li>
# </ul>
# </h3>

# %%
# Ajustando uma distribuição normal aos valores da coluna "fixed acidity" do DataFrame.
(mu, sigma) = norm.fit(df_red["fixed acidity"])
print("mu {} : {}, sigma {} : {}".format("fixed acidity", mu, "fixed acidity", sigma))
# Out:
# mu fixed acidity : 1.124655731469057, sigma fixed acidity : 0.048378082803535

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df_red["fixed acidity"], fit=norm, color="purple")
plt.title("Acidez Fixa Distplot", color = "darkred")
plt.subplot(1,2,2)
stats.probplot(df_red["fixed acidity"], plot = plt)
plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Ao analisarmos os gráficos anteriores e atuais, podemos observar que alcançamos um bom nível de eliminação da assimetria.</p> </li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Açúcar Residual</h4>

# %%
# Ajustando uma distribuição normal aos valores da coluna "residual sugar" do DataFrame.
(mu, sigma) = norm.fit(df_red["residual sugar"])
print("mu {} : {}, sigma {} : {}".format("residual sugar", mu, "residual sugar", sigma))
# Out:
# mu residual sugar : 2.53880550343965, sigma residual sugar : 1.4094871124880495

# %%
# cria uma figura com dois subplots lado a lado, esses gráficos são úteis para visualizar a distribuição e a normalidade dos dados.
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df_red["residual sugar"], fit=norm, color="purple")
plt.title("Açúcar Residual Distplot", color = "darkred")
plt.subplot(1,2,2)
stats.probplot(df_red["residual sugar"], plot = plt)
plt.show()

# %%
# Utilizar a função Box-Cox para transformação estatística de estabilizar a variância e melhorar a normalidade dos dados.
df_red["residual sugar"], lam_fixed_acidity = boxcox(df_red["residual sugar"])

# %%
# Ajustando uma distribuição normal aos valores da coluna "residual sugar" do DataFrame.
(mu, sigma) = norm.fit(df_red["residual sugar"])
print("mu {} : {}, sigma {} : {}".format("residual sugar", mu, "residual sugar", sigma))
# Out:
# mu residual sugar : 0.5135558435839319, sigma residual sugar : 0.11004598444169933

# %%
# cria uma figura com dois subplots lado a lado, esses gráficos são úteis para visualizar a distribuição e a normalidade dos dados.
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df_red["residual sugar"], fit=norm, color="purple")
plt.title("Açúcar Residual Distplot", color = "darkred")
plt.subplot(1,2,2)
stats.probplot(df_red["residual sugar"], plot = plt)
plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Dióxido de Enxofre Livre</h3>

# %%
# Ajustando uma distribuição normal aos valores da coluna "free sulfur dioxide" do DataFrame.
(mu, sigma) = norm.fit(df_red["free sulfur dioxide"])
print("mu {} : {}, sigma {} : {}".format("free sulfur dioxide", mu, "free sulfur dioxide", sigma))
# Out:
# mu free sulfur dioxide : 15.874921826141339, sigma free sulfur dioxide : 10.45688561493072

# %%
# cria uma figura com dois subplots lado a lado, esses gráficos são úteis para visualizar a distribuição e a normalidade dos dados.
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df_red["free sulfur dioxide"], fit=norm, color="purple")
plt.title("Dióxido de Enxofre Livre Distplot", color = "darkred")
plt.subplot(1,2,2)
stats.probplot(df_red["free sulfur dioxide"], plot = plt)
plt.show()

# %%
# Utilizar a função Box-Cox para transformação estatística de estabilizar a variância e melhorar a normalidade dos dados.
df_red["free sulfur dioxide"], lam_fixed_acidity = boxcox(df_red["free sulfur dioxide"])

# %%
# Ajustando uma distribuição normal aos valores da coluna "free sulfur dioxide" do DataFrame.
(mu, sigma) = norm.fit(df_red["free sulfur dioxide"])
print("mu {} : {}, sigma {} : {}".format("free sulfur dioxide", mu, "free sulfur dioxide", sigma))
# Out:
# mu free sulfur dioxide : 3.1290485296425143, sigma free sulfur dioxide : 0.9855086968773705

# %%
# cria uma figura com dois subplots lado a lado, esses gráficos são úteis para visualizar a distribuição e a normalidade dos dados.
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df_red["free sulfur dioxide"], fit=norm, color="purple")
plt.title("Dióxido de Enxofre Livre Distplot", color = "darkred")
plt.subplot(1,2,2)
stats.probplot(df_red["free sulfur dioxide"], plot = plt)
plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Dióxido de Enxofre Total</h3>

# %%
# Ajustando uma distribuição normal aos valores da coluna "total sulfur dioxide" do DataFrame.
(mu, sigma) = norm.fit(df_red["total sulfur dioxide"])
print("mu {} : {}, sigma {} : {}".format("total sulfur dioxide", mu, "total sulfur dioxide", sigma))
# Out:
# mu total sulfur dioxide : 46.46779237023139, sigma total sulfur dioxide : 32.88503665178374

# %%
# cria uma figura com dois subplots lado a lado, esses gráficos são úteis para visualizar a distribuição e a normalidade dos dados.
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df_red["total sulfur dioxide"], fit=norm, color="purple")
plt.title("Dióxido de Enxofre Total Distplot", color = "darkred")
plt.subplot(1,2,2)
stats.probplot(df_red["total sulfur dioxide"], plot = plt)
plt.show()

# %%
# Utilizar a função Box-Cox para transformação estatística de estabilizar a variância e melhorar a normalidade dos dados.
df_red["total sulfur dioxide"], lam_fixed_acidity = boxcox(df_red["total sulfur dioxide"])

# %%
# Ajustando uma distribuição normal aos valores da coluna "total sulfur dioxide" do DataFrame.
(mu, sigma) = norm.fit(df_red["total sulfur dioxide"])
print("mu {} : {}, sigma {} : {}".format("total sulfur dioxide", mu, "total sulfur dioxide", sigma))
# Out:
# mu total sulfur dioxide : 3.9657192644535324, sigma total sulfur dioxide : 0.8459104716754929

# %%
# cria uma figura com dois subplots lado a lado, esses gráficos são úteis para visualizar a distribuição e a normalidade dos dados.
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df_red["total sulfur dioxide"], fit=norm, color="purple")
plt.title("Dióxido de Enxofre Total Distplot", color = "darkred")
plt.subplot(1,2,2)
stats.probplot(df_red["total sulfur dioxide"], plot = plt)
plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Sulfatos</h3>

# %%
# Ajustando uma distribuição normal aos valores da coluna "alcohol" do DataFrame.
(mu, sigma) = norm.fit(df_red["alcohol"])
print("mu {} : {}, sigma {} : {}".format("alcohol", mu, "alcohol", sigma))
# Out:
# mu alcohol : 10.422983114446529, sigma alcohol : 1.0653343003437483

# %%
# cria uma figura com dois subplots lado a lado, esses gráficos são úteis para visualizar a distribuição e a normalidade dos dados.
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df_red["alcohol"], fit=norm, color="purple")
plt.title("Álcool Distplot", color = "darkred")
plt.subplot(1,2,2)
stats.probplot(df_red["alcohol"], plot = plt)
plt.show()

# %%
# Utilizar a função Box-Cox para transformação estatística de estabilizar a variância e melhorar a normalidade dos dados.
df_red["alcohol"], lam_fixed_acidity = boxcox(df_red["alcohol"])

# %%
# Ajustando uma distribuição normal aos valores da coluna "alcohol" do DataFrame.
(mu, sigma) = norm.fit(df_red["alcohol"])
print("mu {} : {}, sigma {} : {}".format("alcohol", mu, "alcohol", sigma))
# Out:
# mu alcohol : 0.3005237243397624, sigma alcohol : 3.922651387741175e-05

# %%
# cria uma figura com dois subplots lado a lado, esses gráficos são úteis para visualizar a distribuição e a normalidade dos dados.
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df_red["alcohol"], fit=norm, color="purple")
plt.title("Álcool Distplot", color = "darkred")
plt.subplot(1,2,2)
stats.probplot(df_red["alcohol"], plot = plt)
plt.show()

# %% [markdown]
# # 📋 7 - Detecção de Outliers

# %% [markdown]
# Identificamos outliers em nossos dados e procederemos com sua remoção.

# %%
# Essa função tem como objetivo detectar e retornar os índices dos outliers presentes no dataframe para as características especificadas.

def detect_outliers(df,features):
    outlier_indices = []
    
    for c in features:
        # 1st quartil
        Q1 = np.percentile(df[c],25)
        # 3st quartil
        Q3 = np.percentile(df[c],75)
        # IQR
        IQR = Q3 - Q1
        # Outlier Etapa
        outlier_step = IQR * 1.5
        # detectar outliers e seus índices
        outlier_list_col = df[(df[c] < Q1 - outlier_step) | (df[c] > Q3 + outlier_step)].index
        # armazenar índices 
        outlier_indices.extend(outlier_list_col)
        
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(i for i, v in outlier_indices.items() if v > 1.5) 
    
    return multiple_outliers

# %%
# Imprimir o número de outliers detectados em um conjunto de dados e, em seguida, retorna os registros que foram identificados como outliers.
print("número de outliers detectados --> ",len(df_red.loc[detect_outliers(df_red,df_red.columns[:-1])]))
df_red.loc[detect_outliers(df_red,df_red.columns[:-1])]
# Out:
# número de outliers detectados -->  68
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 45         0.956497             0.520         0.15        0.494302      0.054
# 94         0.985731             1.020         0.04        0.277689      0.045
# 95         0.964194             0.600         0.17        0.530233      0.058
# 442        1.257350             0.685         0.76        0.666360      0.100
# 553        0.985731             1.040         0.24        0.360736      0.050
# ...             ...               ...          ...             ...        ...
# 1319       1.153967             0.760         0.68        0.394331      0.414
# 1370       1.143543             0.780         0.51        0.394331      0.415
# 1371       1.106811             0.580         0.56        0.624358      0.153
# 1372       1.143543             0.780         0.51        0.394331      0.415
# ...

# %%
# Remover as linhas do dataframe que contêm outliers.
df_red =df_red.drop(detect_outliers(df_red,df_red.columns[:-1]),axis = 0).reset_index(drop = True)

# %% [markdown]
# Removemos os outliers detectados de nossos dados.

# %% [markdown]
# # 📋 8 - Modelagem

# %% [markdown]
# <h2 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold"><p>Agora nossos dados estão prontos para o modelo. Vamos analisar e criar o melhor modelo.</p>
# </h2>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" > Import Model Library </p> </li>
#         <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" > Train - Test Split </p> </li>
#         <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >Smote </p> </li>
#         <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" > StandardScaler </p> </li>
#             <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >KNeighborsClassifier </p> </li>
#                 <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >GradientBoostingClassifier </p> </li>
#                 <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >SVC </p> </li>
#                     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >XGBClassifier </p> </li>
#                     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >CatBoostClassifier </p> </li>
#                     <li style = "color:purple"> <p style = "color:white;font-family:Arial;font-weight:bold" >RandomForestClassifier </p> </li>
#
# </ul>
# </h3>

# %% [markdown]
# <h2 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Import Model Library</h2>

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, RandomizedSearchCV
from sklearn.svm import SVC
from scipy.stats import uniform as sp_randFloat
from scipy.stats import randint as sp_randInt  
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import collections

# %%
# Vamos transformar uma variável numérica em uma variável categórica(atributos qualitativos) por meio da divisão em intervalos específicos.

bins = (2, 6.5, 8)
labels = [0, 1]
df_red['quality'] = pd.cut(x = df_red['quality'], bins = bins, labels = labels)

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Transformamos a variável quality que era de 3 a 8 em 2 variáveis, 0 e 1.</h3>

# %%
df_red['quality'].value_counts()
# Out:
# 0    1323
# 1     208
# Name: quality, dtype: int64

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">
# <ul>
#     <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >0 --> 1323</p> </li>
#         <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >1 --> 208</p> </li>
#         <li style = "color:purple;font-family:Segoe Print" > <p style = "color:white;font-family:Arial" >Percebemos uma significativa disparidade entre os dois valores, o que indica um desequilíbrio evidente. Diante disso, tomaremos as medidas necessárias para corrigir essa situação.</p> </li>
# </ul>
# </h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Train - Test Split</h3
# >

# %%
y = df_red.quality
x = df_red.drop(["quality"], axis = 1)

# %%
test_size = 0.20
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = test_size, random_state = 206)

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Smote</h3>

# %% [markdown]
# Vimos acima que nossos dados são dados não balanceados. Vamos Corrigir o problema de desequilíbrio de classes com o smote.

# %%
sm = SMOTE(random_state=14)
X_train_sm, y_train_sm = sm.fit_resample(X_train, Y_train)

# %%
print("Antes smote --> ", collections.Counter(Y_train))
print("Depois smote --> ", collections.Counter(y_train_sm))
# Out:
# Antes smote -->  Counter({0: 1052, 1: 172})
# Depois smote -->  Counter({0: 1052, 1: 1052})

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">StandardScaler</h3>

# %%
scaler = StandardScaler()
X_train_sm = scaler.fit_transform(X_train_sm) 
X_test = scaler.transform(X_test)

# %%
results = []

# %% [markdown]
# Criamos uma lista para registrar nossas conquistas com os modelos.

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">KNeighborsClassifier</h3>

# %%
knn = KNeighborsClassifier(n_neighbors = 2)
knn.fit(X_train_sm, y_train_sm)
y_pred = knn.predict(X_test)
cm = confusion_matrix(Y_test, y_pred)

acc = accuracy_score(Y_test, y_pred)
score = knn.score(X_test, Y_test)
results.append(acc)

print("Score : ", score)
print("KNeighborsClassifier Acc : ", acc)

plot_confusion_matrix(knn, X_test, Y_test, cmap= "Greens")  
plt.show()
# Out:
# Score :  0.9283387622149837
# KNeighborsClassifier Acc :  0.9283387622149837

# %% [markdown]
# Analisamos a matriz de confusão e agora vamos examinar o relatório de classificação do modelo de aprendizado de máquina.

# %%
print(" \t \t  KNN Classification Report")
print(classification_report(Y_test, y_pred))
# Out:
#  	 	  KNN Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       271
#            1       0.66      0.81      0.73        36
#
#     accuracy                           0.93       307
#    macro avg       0.82      0.88      0.84       307
# weighted avg       0.94      0.93      0.93       307

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">GradientBoostingClassifier</h3>

# %%
gbc = GradientBoostingClassifier(max_depth= 6, random_state=2)
gbc.fit(X_train_sm, y_train_sm)
y_pred_gbc = gbc.predict(X_test)
cm_aaa = confusion_matrix(Y_test, y_pred_gbc)
acc = accuracy_score(Y_test, y_pred_gbc)
score = gbc.score(X_test, Y_test)
results.append(acc)

print("Score : ", score)
print("GradientBoostingClassifier Acc : ", acc)

plot_confusion_matrix(gbc, X_test, Y_test, cmap= "binary")  
plt.show()
# Out:
# Score :  0.9315960912052117
# GradientBoostingClassifier Acc :  0.9315960912052117

# %%
print(" \t \t  GradientBoostingClassifier Classification Report")
print(classification_report(Y_test, y_pred_gbc))
# Out:
#  	 	  GradientBoostingClassifier Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       271
#            1       0.67      0.81      0.73        36
#
#     accuracy                           0.93       307
#    macro avg       0.82      0.88      0.85       307
# weighted avg       0.94      0.93      0.93       307

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">SVC</h3>

# %%
svc = SVC()
svc.fit(X_train_sm, y_train_sm)
pred_svc = svc.predict(X_test)

cm_svc = confusion_matrix(Y_test, pred_svc)
acc = accuracy_score(Y_test, pred_svc)
score = svc.score(X_test, Y_test)
results.append(acc)

print("Score : ", score)
print("SVC Acc : ", acc)

plot_confusion_matrix(svc, X_test, Y_test, cmap= "Reds")  
plt.show()
# Out:
# Score :  0.8599348534201955
# SVC Acc :  0.8599348534201955

# %%
print(" \t \t  SVC Classification Report")
print(classification_report(Y_test, pred_svc))
# Out:
#  	 	  SVC Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.92       271
#            1       0.45      0.83      0.58        36
#
#     accuracy                           0.86       307
#    macro avg       0.71      0.85      0.75       307
# weighted avg       0.91      0.86      0.88       307

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">XGBClassifier</h3>

# %%
xgb = XGBClassifier()
xgb.fit(X_train_sm, y_train_sm)
pred_xgb = xgb.predict(X_test)

cm_aaa = confusion_matrix(Y_test, pred_xgb)
acc = accuracy_score(Y_test, pred_xgb)
score = xgb.score(X_test, Y_test)
results.append(acc)

print("Score : ", score)
print("XGBClassifier Acc : ", acc)

plot_confusion_matrix(xgb, X_test, Y_test, cmap= "copper")  
plt.show()
# Out:
# Score :  0.9381107491856677
# XGBClassifier Acc :  0.9381107491856677

# %%
print(" \t \t  XGBClassifier Classification Report")
print(classification_report(Y_test, pred_xgb))
# Out:
#  	 	  XGBClassifier Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       271
#            1       0.72      0.78      0.75        36
#
#     accuracy                           0.94       307
#    macro avg       0.84      0.87      0.86       307
# weighted avg       0.94      0.94      0.94       307

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">CatBoostClassifier</h3>

# %%
parameters = {  
                'depth'         : sp_randInt(4, 10),
                'learning_rate' : sp_randFloat(),
                'iterations'    : sp_randInt(10, 100)
             }

# %%
cat = CatBoostClassifier(iterations=1000, verbose = False, depth=8)
randm = RandomizedSearchCV(estimator=cat, param_distributions = parameters, 
                               cv = 2, n_iter = 10, n_jobs=-1)
randm.fit(X_train_sm, y_train_sm)

pred_cat = randm.predict(X_test)

cm_cat = confusion_matrix(Y_test, pred_cat)
acc = accuracy_score(Y_test, pred_cat)
score = randm.score(X_test, Y_test)
results.append(acc)

print("Score : ", score)
print("Basic KNN Acc : ", acc)

plot_confusion_matrix(randm, X_test, Y_test, cmap= "hot")  
plt.show()
# Out:
# Score :  0.9218241042345277
# Basic KNN Acc :  0.9218241042345277

# %%
print(" \t \t  CatBoostClassifier Classification Report")
print(classification_report(Y_test, pred_cat))
# Out:
#  	 	  CatBoostClassifier Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95       271
#            1       0.62      0.83      0.71        36
#
#     accuracy                           0.92       307
#    macro avg       0.80      0.88      0.83       307
# weighted avg       0.94      0.92      0.93       307

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">RandomForestClassifier</h3>

# %%
rf = RandomForestClassifier(max_depth=18, random_state=44, bootstrap = False)
rf.fit(X_train_sm, y_train_sm)
y_pred_rf = rf.predict(X_test)
cm = confusion_matrix(Y_test, y_pred_rf)

acc = accuracy_score(Y_test, y_pred_rf)
score = rf.score(X_test, Y_test)
results.append(acc)

print("Score : ", score)
print("RandomForestClassifier Acc : ", acc)

plot_confusion_matrix(rf, X_test, Y_test, cmap= "pink")  
plt.show()
# Out:
# Score :  0.9576547231270358
# RandomForestClassifier Acc :  0.9576547231270358

# %%
print(" \t \t  RandomForestClassifier Classification Report")
print(classification_report(Y_test, y_pred_rf))
# Out:
#  	 	  RandomForestClassifier Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       271
#            1       0.81      0.83      0.82        36
#
#     accuracy                           0.96       307
#    macro avg       0.89      0.90      0.90       307
# weighted avg       0.96      0.96      0.96       307

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Alcançamos o melhor resultado com Random Forest. Agora, vamos analisar os erros que foram cometidos.</h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Wrong Predictions</h3>

# %%
test_data = pd.DataFrame()
test_data["citric acid"] = df_red["volatile acidity"][:307]
test_data["fixed acidity"] = df_red["fixed acidity"][:307]
test_data["y_pred_rf"] = y_pred_rf
test_data["Y_test"] = Y_test.values

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="citric acid", y="fixed acidity", hue="Y_test", data=test_data, palette=["Black","darkgreen"])
plt.title("Classificações que Erramos", fontsize = 13, fontweight = "bold", color = "darkred")

diff = np.where(y_pred_rf!=Y_test)[0]
plt.scatter(test_data.iloc[diff,0],test_data.iloc[diff,1],label = "Classificado Errado", marker="x",alpha = 0.7, color = "Red",s = 300)
plt.legend()
plt.show()

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Além disso, também avaliamos cuidadosamente os palpites incorretos, levando em consideração o contexto da (For Random Forest).</h3>

# %% [markdown]
# <h3 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Model Result.</h3>

# %%
df_result = pd.DataFrame({"Score":results, "ML Models":["KNN","GradientBoostingClassifier",
             "SVC","XGBClassifier","CatBoostClassifier","RandomForestClassifier"]})

# %%
df_result.style.background_gradient("Greens")
# Out:
# <style type="text/css">
# #T_c2c28_row0_col0 {
#   background-color: #2f974e;
#   color: #f1f1f1;
# }
# #T_c2c28_row1_col0 {
#   background-color: #278f48;
#   color: #f1f1f1;
# }
# #T_c2c28_row2_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_c2c28_row3_col0 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_c2c28_row4_col0 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_c2c28_row5_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c2c28">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2c28_level0_col0" class="col_heading level0 col0" >Score</th>
#       <th id="T_c2c28_level0_col1" class="col_heading level0 col1" >ML Models</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2c28_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2c28_row0_col0" class="data row0 col0" >0.928339</td>
# ...

# %%
g = sns.barplot("Score", "ML Models", data = df_result, palette='BrBG')
g.set_xlabel("Score")
g.set_title("Classifier Model Results", color = "Black")
plt.show()

# %% [markdown]
# <h2 style = "background:black;color:white;border:0;font-family:Arial;font-weight:bold">Concluindo nossa análise, o modelo de classificação Random Forest obteve um desempenho excepcional, alcançando uma taxa de acerto impressionante de 95,76%.</h2>
